# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# %%
# Helper libraries
import numpy as np
# %matplotlib inline
# import matplotlib
# matplotlib.use('TkAgg')# Backend needed for the Mac virtual env
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 1.12.0

# %%
tf.random.set_random_seed(1) # For reproducibility of initial weights

# %%
# Data set:
# BnW 28x28 pixel handwritten images of digits
# 60000 training samples, 10000 test samples

# Importing data from MNIST server
# mnist = keras.datasets.mnist
#(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Import data locally
train_images = np.load('Data/train_data.npy')
train_labels = np.load('Data/train_data_label.npy')
test_images  = np.load('Data/test_data.npy')
test_labels  = np.load('Data/test_data_labels.npy')

# %%
# Visualize a few of the images
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
plt.show()

# %%
# Function describing network architecture
def create_model():
  model = keras.Sequential([
          keras.layers.Flatten(input_shape=(28, 28)),
          keras.layers.Dense(20, activation=tf.nn.relu, use_bias=True, kernel_initializer='RandomNormal', bias_initializer='RandomNormal'),
          keras.layers.Dense(20, activation=tf.nn.relu, use_bias=True, kernel_initializer='RandomNormal', bias_initializer='RandomNormal'),
          keras.layers.Dense(20, activation=tf.nn.relu, use_bias=True, kernel_initializer='RandomNormal', bias_initializer='RandomNormal'),
          keras.layers.Dense(10, activation=tf.nn.softmax, use_bias=True, kernel_initializer='RandomNormal', bias_initializer='RandomNormal')
  ])
  
  model.compile(optimizer=tf.train.AdamOptimizer(), 
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

model = create_model()
model.summary()
#model.get_weights()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 20)                15700
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                210
# =================================================================
# Total params: 16,750
# Trainable params: 16,750
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training
model.fit(train_images, train_labels, epochs=10, verbose=1, batch_size=32)
# model.fit(train_images, 
#           train_labels, 
#           epochs=10, 
#           verbose=2, 
#           batch_size=32, 
#           shuffle=True, 
#           validation_split=0.1
#           )
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/50
#  - 2s - loss: 0.3744 - acc: 0.8839 - val_loss: 0.1842 - val_acc: 0.9415
# Epoch 2/50
#  - 2s - loss: 0.1964 - acc: 0.9433 - val_loss: 0.1452 - val_acc: 0.9598
# Epoch 3/50
#  - 2s - loss: 0.1650 - acc: 0.9515 - val_loss: 0.1251 - val_acc: 0.9635
# Epoch 4/50
#  - 2s - loss: 0.1445 - acc: 0.9569 - val_loss: 0.1308 - val_acc: 0.9637
# Epoch 5/50
#  - 2s - loss: 0.1336 - acc: 0.9615 - val_loss: 0.1250 - val_acc: 0.9635
# Epoch 6/50
#  - 2s - loss: 0.1254 - acc: 0.9628 - val_loss: 0.1318 - val_acc: 0.9632
# Epoch 7/50
#  - 2s - loss: 0.1178 - acc: 0.9654 - val_loss: 0.1199 - val_acc: 0.9677
# Epoch 8/50
#  - 2s - loss: 0.1092 - acc: 0.9676 - val_loss: 0.1206 - val_acc: 0.9648
# Epoch 9/50
#  - 2s - loss: 0.1073 - acc: 0.9683 - val_loss: 0.1392 - val_acc: 0.9618
# Epoch 10/50
#  - 2s - loss: 0.1015 - acc: 0.9701 - val_loss: 0.1232 - val_acc: 0.9660
# Epoch 11/50
#  - 2s - loss: 0.0999 - acc: 0.9704 - val_loss: 0.1203 - val_acc: 0.9667
# Epoch 12/50
#  - 2s - loss: 0.0950 - acc: 0.9717 - val_loss: 0.1446 - val_acc: 0.9602
# Epoch 13/50
#  - 2s - loss: 0.0931 - acc: 0.9720 - val_loss: 0.1215 - val_acc: 0.9683
# Epoch 14/50
#  - 2s - loss: 0.0903 - acc: 0.9734 - val_loss: 0.1276 - val_acc: 0.9673
# Epoch 15/50
#  - 2s - loss: 0.0879 - acc: 0.9742 - val_loss: 0.1358 - val_acc: 0.9643
# Epoch 16/50
#  - 2s - loss: 0.0879 - acc: 0.9742 - val_loss: 0.1205 - val_acc: 0.9680
# Epoch 17/50
#  - 2s - loss: 0.0856 - acc: 0.9751 - val_loss: 0.1165 - val_acc: 0.9687
# Epoch 18/50
#  - 2s - loss: 0.0822 - acc: 0.9758 - val_loss: 0.1303 - val_acc: 0.9638
# Epoch 19/50
#  - 2s - loss: 0.0813 - acc: 0.9768 - val_loss: 0.1446 - val_acc: 0.9635
# Epoch 20/50
#  - 2s - loss: 0.0767 - acc: 0.9771 - val_loss: 0.1169 - val_acc: 0.9700
# Epoch 21/50
#  - 2s - loss: 0.0797 - acc: 0.9767 - val_loss: 0.1215 - val_acc: 0.9677
# Epoch 22/50
#  - 2s - loss: 0.0812 - acc: 0.9765 - val_loss: 0.1459 - val_acc: 0.9645
# Epoch 23/50
#  - 2s - loss: 0.0769 - acc: 0.9778 - val_loss: 0.1336 - val_acc: 0.9657
# Epoch 24/50
#  - 2s - loss: 0.0725 - acc: 0.9781 - val_loss: 0.1445 - val_acc: 0.9670
# Epoch 25/50
#  - 2s - loss: 0.0720 - acc: 0.9787 - val_loss: 0.1537 - val_acc: 0.9635
# Epoch 26/50
#  - 2s - loss: 0.0710 - acc: 0.9794 - val_loss: 0.1383 - val_acc: 0.9668
# Epoch 27/50
#  - 2s - loss: 0.0713 - acc: 0.9795 - val_loss: 0.1303 - val_acc: 0.9683
# Epoch 28/50
#  - 2s - loss: 0.0715 - acc: 0.9792 - val_loss: 0.1437 - val_acc: 0.9670
# Epoch 29/50
#  - 2s - loss: 0.0693 - acc: 0.9794 - val_loss: 0.1339 - val_acc: 0.9665
# Epoch 30/50
#  - 2s - loss: 0.0670 - acc: 0.9805 - val_loss: 0.1512 - val_acc: 0.9657
# Epoch 31/50
#  - 2s - loss: 0.0655 - acc: 0.9816 - val_loss: 0.1602 - val_acc: 0.9658
# Epoch 32/50
#  - 2s - loss: 0.0675 - acc: 0.9807 - val_loss: 0.1610 - val_acc: 0.9642
# Epoch 33/50
#  - 2s - loss: 0.0641 - acc: 0.9817 - val_loss: 0.1848 - val_acc: 0.9618
# Epoch 34/50
#  - 2s - loss: 0.0649 - acc: 0.9807 - val_loss: 0.1723 - val_acc: 0.9658
# Epoch 35/50
#  - 2s - loss: 0.0623 - acc: 0.9823 - val_loss: 0.1512 - val_acc: 0.9662
# Epoch 36/50
#  - 2s - loss: 0.0628 - acc: 0.9821 - val_loss: 0.1597 - val_acc: 0.9653
# Epoch 37/50
#  - 2s - loss: 0.0609 - acc: 0.9826 - val_loss: 0.1541 - val_acc: 0.9673
# Epoch 38/50
#  - 2s - loss: 0.0583 - acc: 0.9828 - val_loss: 0.1536 - val_acc: 0.9653
# Epoch 39/50
#  - 2s - loss: 0.0601 - acc: 0.9825 - val_loss: 0.1448 - val_acc: 0.9677
# Epoch 40/50
#  - 2s - loss: 0.0612 - acc: 0.9823 - val_loss: 0.1457 - val_acc: 0.9673
# Epoch 41/50
#  - 2s - loss: 0.0586 - acc: 0.9834 - val_loss: 0.1558 - val_acc: 0.9665
# Epoch 42/50
#  - 2s - loss: 0.0581 - acc: 0.9831 - val_loss: 0.1513 - val_acc: 0.9687
# Epoch 43/50
#  - 2s - loss: 0.0593 - acc: 0.9821 - val_loss: 0.1573 - val_acc: 0.9667
# Epoch 44/50
#  - 2s - loss: 0.0598 - acc: 0.9831 - val_loss: 0.1604 - val_acc: 0.9625
# Epoch 45/50
#  - 2s - loss: 0.0574 - acc: 0.9827 - val_loss: 0.1500 - val_acc: 0.9672
# Epoch 46/50
#  - 2s - loss: 0.0551 - acc: 0.9845 - val_loss: 0.1529 - val_acc: 0.9665
# Epoch 47/50
#  - 2s - loss: 0.0573 - acc: 0.9840 - val_loss: 0.1603 - val_acc: 0.9667
# Epoch 48/50
#  - 2s - loss: 0.0550 - acc: 0.9841 - val_loss: 0.1871 - val_acc: 0.9682
# Epoch 49/50
#  - 2s - loss: 0.0528 - acc: 0.9848 - val_loss: 0.1705 - val_acc: 0.9652
# Epoch 50/50
#  - 2s - loss: 0.0556 - acc: 0.9840 - val_loss: 0.1820 - val_acc: 0.9635

# %%
# Test accuracy of trained model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 16us/step
# Test accuracy: 0.9594

# %%
# Making predictions

def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  
  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
  
  plt.xlabel("{:2.0f}% ({})".format(100*np.max(predictions_array),
                                    predicted_label),
                                    color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1]) 
  predicted_label = np.argmax(predictions_array)
 
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')


predictions = model.predict(test_images)  
# Plot the first X test images, their predicted label, and the true label
# Color correct predictions in blue, incorrect predictions in red
num_rows = 10
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
